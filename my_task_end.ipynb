# %% [markdown]
# <center style="font-size: 26px"> <b>Проверка уровня знаний Python</b></center>

# %%
# обеспечиваем совместимость с Python 2 и 3
from __future__ import (absolute_import, division, print_function, unicode_literals)

# отключаем предупреждения дистрибутива Anaconda
import warnings
warnings.simplefilter('ignore')
# основные библиотеки|
import pandas as pd

# дополнительные библиотеки
import requests
import xml.etree.ElementTree as ET
import datetime
import re

# %% [markdown]
# **Описание датасета:**
# [Датасет вакансий с платформы HH.ru на Kaggle.com](https://www.kaggle.com/datasets/pavfedotov/heaadhunter-vacancies?resource=download&select=df2021-08-03.csv)
#
# Нужный файл - df2021-08-03.csv.
#
# - *vacancy* - наименование вакансии
# - *url* - ссылка на вакансию
# - *created* - дата и время создания
# - *has_test* - наличие тестового задания в вакансии
# - *salary_from* - нижняя граница значения заработной платы
# - *salary_to* - верхняя граница значения заработной платы
# - *currency* - валюта заработной платы
# - *experience* - требуемый опыт
# - *schedule* - тип рабочего графика
# - *skills* - требуемые навыки
# - *employer* - наименование работодателя
# - *area* - наименование города
# - *description* - описание вакансии

# %% [markdown]
# #### Загрузите датасет

# %%
# ВАШ КОД ЗДЕСЬ
df = pd.read_csv('df2021-08-03.csv')

# %%
df.dtypes
# Out:
# vacancy         object
# url             object
# created         object
# has_test          bool
# salary_from    float64
# salary_to      float64
# currency        object
# experience      object
# schedule        object
# skills          object
# employer        object
# area            object
# description     object
# dtype: object

# %%
# приведём столбец с датами к формату даты
df['created'] = pd.to_datetime(df['created'])
df['created'] = df['created'].dt.strftime('%Y-%m-%d')

# %%
# зарплату к числовому виду
df['salary_from'] = df['salary_from'].astype(float)
df['salary_to'] = df['salary_to'].astype(float)

# %%
df.isna().sum()
# Out:
# vacancy           0
# url               0
# created           0
# has_test          0
# salary_from    1162
# salary_to      1267
# currency       1087
# experience        0
# schedule          0
# skills          210
# employer          0
# area              0
# description       0
# dtype: int64

# %% [markdown]
# ### Практические задания:

# %% [markdown]
# #### 1. Изучите методы для сбора данных курсов валют в [API Центрального банка Российской Федерации](https://www.cbr.ru/development/SXML/) . Используя запросы к API, приведите значения заработной платы к рублям одним из вариантов: 1) простой вариант - на текущую дату  2) вариант посложнее - на дату создания (created).

# %%
# Выберем вариант 1 - на текущую дату.

# %%
# какие валюты представлены
df.currency.unique()
# Out:
# array(['RUR', nan, 'EUR', 'USD'], dtype=object)

# %%
# ВАШ КОД ЗДЕСЬ

# выполним запрос к апи ЦБ РФ
# возьмём курс $ на сегодняшнюю дату
usd_rate = float(
                ET.fromstring(requests.get('http://www.cbr.ru/scripts/XML_daily.asp').text)
                .find("./Valute[CharCode='USD']/Value")
                .text.replace(",","."))


# выполним запрос к апи ЦБ РФ
# возьмём курс € на сегодняшнюю дату
euro_rate = float(
                ET.fromstring(requests.get('http://www.cbr.ru/scripts/XML_daily.asp').text)
                .find("./Valute[CharCode='EUR']/Value")
                .text.replace(",","."))


# приведём валюты к рублю
for i in range(len(df)):
    
    if df['currency'][i] == "USD":
        
        df['currency'][i] = "RUR"
        
        df['salary_to'][i]  = df['salary_to'][i]*usd_rate
        df['salary_from'][i]  = df['salary_from'][i]*usd_rate
        
    elif df['currency'][i] == "EUR":
        
        df['currency'][i] = "RUR"
        
        df['salary_to'][i]  = df['salary_to'][i]*euro_rate
        df['salary_from'][i]  = df['salary_from'][i]*euro_rate
        
    else:
        pass

# %%
# данные приведены к рублям
df.currency.unique()
# Out:
# array(['RUR', nan], dtype=object)

# %%
# сохраним полученный датафрейм, чтобы поработать с ним в PowerBI
df.to_csv('test_bi.csv', index=False)

# %% [markdown]
# #### 2. Найдите вакансию с самой высокой заработной платой, где подойдет 4 года опыта работы и не нужно проходить тестовое задание.

# %%
# посмотрим возможные интервалы опыта
df.experience.unique()
# Out:
# array(['От 1 года до 3 лет', 'От 3 до 6 лет', 'Нет опыта', 'Более 6 лет'],
#       dtype=object)

# %%
highest_salary = df
# примем, что фактическая заработная плата - среднее зарплатной вилки
highest_salary['salary'] = (highest_salary['salary_from'] + highest_salary['salary_to'])/2

# %%
highest_salary = highest_salary.query('(experience == "От 3 до 6 лет") and (has_test == False)')\
    .sort_values(by = 'salary', ascending = False)

# %%
#  вакансия с самой высокой зарплатной вилкой, где подойдет 4 года опыта работы и не нужно проходить тестовое задание.
highest_salary.head(1)
# Out:
#               vacancy                                                url
# 191  Python Developer  https://hh.ru/applicant/vacancy_response?vacan...  \
#
#         created  has_test  salary_from  salary_to currency     experience
# 191  2021-08-02     False     355253.2   532879.8      RUR  От 3 до 6 лет  \
#
#              schedule                                            skills
# 191  Удаленная работа  Python;Django Framework;Git;SQL;PostgreSQL;REST;  \
#
#               employer    area
# 191  Top Remote Talent  Москва  \
#
#                                            description    salary
# 191  A Dubai based startup in the PropTech industry...  444066.5

# %% [markdown]
# #### 3. Сделайте рейтинг (топ-30) навыков по всем вакансиям.

# %%
# ВАШ КОД ЗДЕСЬ

# разобьём списки со скиллами на подстроки
df['skills'] = df['skills'].apply(lambda x: str(x).split(';'))

# добавим все значения, не исключая повторение, в один список
skill = []
for x in range(len(df)):
    skill.extend(df['skills'][x])
    
# создадим отдельный df для возможного использования полученных данных вспоследствии
skill_count = {}
for x in skill:
    skill_count[x] = skill.count(x)
skill_df = pd.DataFrame(list(skill_count.items()), columns=['Skill', 'Count']).query("Skill != ''")

# топ 30 навыков по всем вакансиям по числу упоминаний
skill_df = skill_df.sort_values('Count', ascending = False).head(30)
skill_df
# Out:
#                 Skill  Count
# 0              Python   1442
# 5                 Git    586
# 25                SQL    501
# 1          PostgreSQL    499
# 9    Django Framework    467
# 2               Linux    463
# 15                nan    210
# 3               Flask    177
# 30             Docker    172
# 19         JavaScript    149
# 32    Английский язык    141
# 23              MySQL    128
# 42                ООП    120
# 6             MongoDB    113
# 7               Redis    107
# 81               REST     70
# 54           RabbitMQ     68
# 58             Django     62
# 11                CSS     56
# 48               HTML     56
# 40     Atlassian Jira     52
# 21                C++     50
# 94                API     49
# 63             MS SQL     43
# 128              Java     43
# 24        Базы данных     41
# 60   Работа в команде     39
# 27                AWS     36
# 43             Celery     35
# 12             Pytest     35

# %%
# сохраним полученный датафрейм, чтобы поработать с ним в PowerBI
skill_df.to_csv('skills_bi.csv', index=False)

# %% [markdown]
# #### 4. Cоставьте топ-10 городов с наибольшей средней заработной платой по вакансиям тестировщика (QA).

# %%
# ВАШ КОД ЗДЕСЬ

# вакансии тестировщиков
# примем, что SDET тоже попадает по вакансии тестировщиков
# эдакий прокачанный qa
qa_df = df[df['vacancy'].str.contains(r'qa|test|тест|uat|assurance', case=False)]

# подсчитаем без учёта отсутствия данных по зарплате
qa_df['salary'] = (qa_df['salary_from'] + qa_df['salary_to'])/2
qa_df.groupby('area', as_index = False).agg({'salary_from':'mean','salary_to':'mean', 'salary':'mean' })\
    .sort_values(by = 'salary_from', ascending = False)
# Out:
#                                   area    salary_from      salary_to    salary
# 6                               Москва  171826.655556  183750.000000  147500.0
# 16                              Тамбов  150000.000000  250000.000000  200000.0
# 12                     Санкт-Петербург  148000.000000  209285.714286  175000.0
# 4                               Казань   90000.000000            NaN       NaN
# 0                               Брянск            NaN            NaN       NaN
# 1    Дзержинск (Нижегородская область)            NaN            NaN       NaN
# 2                         Димитровград            NaN            NaN       NaN
# 3                         Екатеринбург            NaN            NaN       NaN
# 5                            Краснодар            NaN            NaN       NaN
# 7                      Нижний Новгород            NaN            NaN       NaN
# 8                          Новосибирск            NaN            NaN       NaN
# 9   Первомайск (Нижегородская область)            NaN            NaN       NaN
# 10                      Ростов-на-Дону            NaN            NaN       NaN
# 11                              Самара            NaN            NaN       NaN
# 13                             Саранск            NaN            NaN       NaN
# 14                             Саратов            NaN            NaN       NaN
# 15                                Сочи            NaN            NaN       NaN
# 17                               Томск            NaN            NaN       NaN
# 18                           Ульяновск            NaN            NaN       NaN

# %% [markdown]
# #### 5. Напишите функцию для поиска вакансий по переданным в нее значениям заработной платы, наличия тестового задания, наличия заданного текста в наименовании вакансии, наличия заданного навыка. В результате выведите количество найденных вакансий, среднюю заработную плату по найденным вакансиям и список ссылок найденных вакансий.

# %%
# ВАШ КОД ЗДЕСЬ
def vacancy(data, salary_from = False, salary_to = False, test = 0, text = False, skill = False):
    
    '''
    на вход принимает 
    1. data - данные по вакансиями (обязательный параметр)
    
    2. salary_from - нижний порог зарплаты (опционально)
    
    3. salary_to - верхний порог зарплаты (опционально)
    
    4. test - True или False (опционально)
    
    5. text - заданный текст в наименовании вакансии, нерегистрозависимый, передавать в кавычках через запятую без пробелов (опционально)
    
    6. skill - заданный навык (опционально). Если требуется несколько, перечислите их через запятую без пробелов.
    Наличие или всех навыков, или какого-то среза из заданного списка.
    
    '''
    
    
    
    vacancy_df = data
    
    test = test
    
    salary_from = float(salary_from)
    
    salary_to = float(salary_to)
    
    vacancy_text = text
    
    skills = skill
    
    # поработаем с типом данных
    vacancy_df['created'] = pd.to_datetime(vacancy_df['created'])
    vacancy_df['created'] = vacancy_df['created'].dt.strftime('%Y-%m-%d')
    vacancy_df['salary_from'] = vacancy_df['salary_from'].astype(float)
    vacancy_df['salary_to'] = vacancy_df['salary_to'].astype(float)
    
    # Пусть функция принимает значения в рублях (можно сделать и с выбором валюты, но в условии этого не задано)
    # Переведём валюты в рубли
    
    # возьмём курс $ на сегодняшнюю дату
    usd_rate = float(
                    ET.fromstring(requests.get('http://www.cbr.ru/scripts/XML_daily.asp').text)
                    .find("./Valute[CharCode='USD']/Value")
                    .text.replace(",","."))


    # выполним запрос к апи ЦБ РФ
    # возьмём курс € на сегодняшнюю дату
    euro_rate = float(
                    ET.fromstring(requests.get('http://www.cbr.ru/scripts/XML_daily.asp').text)
                    .find("./Valute[CharCode='EUR']/Value")
                    .text.replace(",","."))


    # приведём валюты к рублю
    for i in range(len(df)):

        if vacancy_df['currency'][i] == "USD":

            vacancy_df['currency'][i] = "RUR"

            vacancy_df['salary_to'][i]  = df['salary_to'][i]*usd_rate
            vacancy_df['salary_from'][i]  = df['salary_from'][i]*usd_rate

        elif vacancy_df['currency'][i] == "EUR":

            vacancy_df['currency'][i] = "RUR"

            vacancy_df['salary_to'][i]  = df['salary_to'][i]*euro_rate
            vacancy_df['salary_from'][i]  = df['salary_from'][i]*euro_rate

        else:
            pass
        
    if salary_from != False:
        
        #значение минимальной заработной платы
        vacancy_df = vacancy_df.query('salary_from >= @salary_from')
        
    else:
        pass
    
    if salary_to != False:
        
        #значение максимальной заработной платы
        vacancy_df = vacancy_df.query('salary_to <= @salary_to')
        
    else:
        pass
    
    # наличие тестового задания
    if test == True:
        
        vacancy_df = vacancy_df.query('has_test == True')
        
    elif test == False:
        
        vacancy_df = vacancy_df.query('has_test == False')
        
    else:
        pass
    
    # наличие заданного текста в вакансии
    if vacancy_text != False:
        
        # требуемые слова
        words = vacancy_text.split(',')
        vacancy_pattern = '|'.join(words)
        
        # ищем слова
        vacancy_df = vacancy_df[vacancy_df['vacancy'].str.contains(vacancy_pattern, case=False, regex = True)]
        
    else:
        pass

    # наличие заданного навыка (-ов)
    if skills != False:
        
        skill_words = skills.split(',')
        skill_pattern = '|'.join(skill_words)
        vacancy_df = vacancy_df[vacancy_df['skills'].str.contains(skill_pattern, case=False, na = False)]
        
    else:
        pass
    
    # количество вакансий
    vacancies_number = str(vacancy_df.shape[0])
    
    print("Вакансий найдено: " + vacancies_number)
    
    # в среднем зп начинается от:
    mean_salary_from = str(vacancy_df['salary_from'].mean())
    
    print("Заработная плата в среднем начинается от " + mean_salary_from)
    
    # ссылки на вакансии
    print("Ссылки на вакансии по запросу:")
          
    for x in vacancy_df['url']:
        print(str(x))
    
    return(vacancy_df)

# %%
print(vacancy.__doc__)
# Out:
#     на вход принимает
#     1. data - данные по вакансиями (обязательный параметр)
#
#     2. salary_from - нижний порог зарплаты (опционально)
#
#     3. salary_to - верхний порог зарплаты (опционально)
#
#     4. test - True или False (опционально)
#
#     5. text - заданный текст в наименовании вакансии, нерегистрозависимый, передавать в кавычках через запятую без пробелов (опционально)
#
#     6. skill - заданный навык (опционально). Если требуется несколько, перечислите их через запятую без пробелов.
#     Наличие или всех навыков, или какого-то среза из заданного списка.

# %% [markdown]
# #### *Необязательно*. Усложненный вариант - сделать атрибуты функции опциональными, чтобы иметь возможность фильтрации вакансий по любой комбинации условий.

# %%
# ВАШ КОД ЗДЕСЬ

# %%
df = pd.read_csv('df2021-08-03.csv')
vacancy_df = vacancy(df,0, 20000000, test = False, text = "python,senior", skill = "PHP,sql")
# Out:
# Вакансий найдено: 226
# Заработная плата в среднем начинается от 123070.38581005586
# Ссылки на вакансии по запросу:
# https://hh.ru/applicant/vacancy_response?vacancyId=46030221
# https://hh.ru/applicant/vacancy_response?vacancyId=42905077
# https://hh.ru/applicant/vacancy_response?vacancyId=46614391
# https://hh.ru/applicant/vacancy_response?vacancyId=46575862
# https://hh.ru/applicant/vacancy_response?vacancyId=45924294
# https://hh.ru/applicant/vacancy_response?vacancyId=46386511
# https://hh.ru/applicant/vacancy_response?vacancyId=46325809
# https://hh.ru/applicant/vacancy_response?vacancyId=37029603
# https://hh.ru/applicant/vacancy_response?vacancyId=43674070
# https://hh.ru/applicant/vacancy_response?vacancyId=45797134
# https://hh.ru/applicant/vacancy_response?vacancyId=46089335
# https://hh.ru/applicant/vacancy_response?vacancyId=43674066
# https://hh.ru/applicant/vacancy_response?vacancyId=46141622
# https://hh.ru/applicant/vacancy_response?vacancyId=46173267
# https://hh.ru/applicant/vacancy_response?vacancyId=46662814
# https://hh.ru/applicant/vacancy_response?vacancyId=43674084
# https://hh.ru/applicant/vacancy_response?vacancyId=46259725
# https://hh.ru/applicant/vacancy_response?vacancyId=46260986
# https://hh.ru/applicant/vacancy_response?vacancyId=46008191
# https://hh.ru/applicant/vacancy_response?vacancyId=38792841
# https://hh.ru/applicant/vacancy_response?vacancyId=46144590
# https://hh.ru/applicant/vacancy_response?vacancyId=46252392
# https://hh.ru/applicant/vacancy_response?vacancyId=45826170
# https://hh.ru/applicant/vacancy_response?vacancyId=45806688
# https://hh.ru/applicant/vacancy_response?vacancyId=46615191
# https://hh.ru/applicant/vacancy_response?vacancyId=46670558
# https://hh.ru/applicant/vacancy_response?vacancyId=44626254
# https://hh.ru/applicant/vacancy_response?vacancyId=46252402
# https://hh.ru/applicant/vacancy_response?vacancyId=41541061
# https://hh.ru/applicant/vacancy_response?vacancyId=45061368
# https://hh.ru/applicant/vacancy_response?vacancyId=46625950
# https://hh.ru/applicant/vacancy_response?vacancyId=46670557
# https://hh.ru/applicant/vacancy_response?vacancyId=46582792
# https://hh.ru/applicant/vacancy_response?vacancyId=46582876
# https://hh.ru/applicant/vacancy_response?vacancyId=46684598
# https://hh.ru/applicant/vacancy_response?vacancyId=42615019
# https://hh.ru/applicant/vacancy_response?vacancyId=46497746
# https://hh.ru/applicant/vacancy_response?vacancyId=46328969
# https://hh.ru/applicant/vacancy_response?vacancyId=46618136
# https://hh.ru/applicant/vacancy_response?vacancyId=43856428
# https://hh.ru/applicant/vacancy_response?vacancyId=45989041
# https://hh.ru/applicant/vacancy_response?vacancyId=45560000
# https://hh.ru/applicant/vacancy_response?vacancyId=44936197
# https://hh.ru/applicant/vacancy_response?vacancyId=46166483
# https://hh.ru/applicant/vacancy_response?vacancyId=45978267
# https://hh.ru/applicant/vacancy_response?vacancyId=46370660
# https://hh.ru/applicant/vacancy_response?vacancyId=43941903
# https://hh.ru/applicant/vacancy_response?vacancyId=46192071
# https://hh.ru/applicant/vacancy_response?vacancyId=46736843
# https://hh.ru/applicant/vacancy_response?vacancyId=46204923
# https://hh.ru/applicant/vacancy_response?vacancyId=46143018
# https://hh.ru/applicant/vacancy_response?vacancyId=46657885
# https://hh.ru/applicant/vacancy_response?vacancyId=39736489
# https://hh.ru/applicant/vacancy_response?vacancyId=44570552
# https://hh.ru/applicant/vacancy_response?vacancyId=46117025
# https://hh.ru/applicant/vacancy_response?vacancyId=46582713
# https://hh.ru/applicant/vacancy_response?vacancyId=46411757
# https://hh.ru/applicant/vacancy_response?vacancyId=46449633
# https://hh.ru/applicant/vacancy_response?vacancyId=41727993
# https://hh.ru/applicant/vacancy_response?vacancyId=46603537
# https://hh.ru/applicant/vacancy_response?vacancyId=46166481
# https://hh.ru/applicant/vacancy_response?vacancyId=46428205
# https://hh.ru/applicant/vacancy_response?vacancyId=45987039
# https://hh.ru/applicant/vacancy_response?vacancyId=45974800
# https://hh.ru/applicant/vacancy_response?vacancyId=46166482
# https://hh.ru/applicant/vacancy_response?vacancyId=46674084
# https://hh.ru/applicant/vacancy_response?vacancyId=40676057
# https://hh.ru/applicant/vacancy_response?vacancyId=46496928
# https://hh.ru/applicant/vacancy_response?vacancyId=46017119
# https://hh.ru/applicant/vacancy_response?vacancyId=44010228
# https://hh.ru/applicant/vacancy_response?vacancyId=46422507
# https://hh.ru/applicant/vacancy_response?vacancyId=43258642
# https://hh.ru/applicant/vacancy_response?vacancyId=36606581
# https://hh.ru/applicant/vacancy_response?vacancyId=43954953
# https://hh.ru/applicant/vacancy_response?vacancyId=46468034
# https://hh.ru/applicant/vacancy_response?vacancyId=46563619
# https://hh.ru/applicant/vacancy_response?vacancyId=45511265
# https://hh.ru/applicant/vacancy_response?vacancyId=46682089
# https://hh.ru/applicant/vacancy_response?vacancyId=45357150
# https://hh.ru/applicant/vacancy_response?vacancyId=46297148
# https://hh.ru/applicant/vacancy_response?vacancyId=40551245
# https://hh.ru/applicant/vacancy_response?vacancyId=46548267
# https://hh.ru/applicant/vacancy_response?vacancyId=39339342
# https://hh.ru/applicant/vacancy_response?vacancyId=40728652
# https://hh.ru/applicant/vacancy_response?vacancyId=46700993
# https://hh.ru/applicant/vacancy_response?vacancyId=40376578
# https://hh.ru/applicant/vacancy_response?vacancyId=46304212
# https://hh.ru/applicant/vacancy_response?vacancyId=46124734
# https://hh.ru/applicant/vacancy_response?vacancyId=46230357
# https://hh.ru/applicant/vacancy_response?vacancyId=46212591
# https://hh.ru/applicant/vacancy_response?vacancyId=46166484
# https://hh.ru/applicant/vacancy_response?vacancyId=46673496
# https://hh.ru/applicant/vacancy_response?vacancyId=46079761
# https://hh.ru/applicant/vacancy_response?vacancyId=46117024
# https://hh.ru/applicant/vacancy_response?vacancyId=46266410
# https://hh.ru/applicant/vacancy_response?vacancyId=46016705
# https://hh.ru/applicant/vacancy_response?vacancyId=43615645
# https://hh.ru/applicant/vacancy_response?vacancyId=46205242
# https://hh.ru/applicant/vacancy_response?vacancyId=42587352
# https://hh.ru/applicant/vacancy_response?vacancyId=45840852
# https://hh.ru/applicant/vacancy_response?vacancyId=46657884
# https://hh.ru/applicant/vacancy_response?vacancyId=46491943
# https://hh.ru/applicant/vacancy_response?vacancyId=46491941
# https://hh.ru/applicant/vacancy_response?vacancyId=44863184
# https://hh.ru/applicant/vacancy_response?vacancyId=45128327
# https://hh.ru/applicant/vacancy_response?vacancyId=46491942
# https://hh.ru/applicant/vacancy_response?vacancyId=40278614
# https://hh.ru/applicant/vacancy_response?vacancyId=45128326
# https://hh.ru/applicant/vacancy_response?vacancyId=43343275
# https://hh.ru/applicant/vacancy_response?vacancyId=46657886
# https://hh.ru/applicant/vacancy_response?vacancyId=46243210
# https://hh.ru/applicant/vacancy_response?vacancyId=46349821
# https://hh.ru/applicant/vacancy_response?vacancyId=46309107
# https://hh.ru/applicant/vacancy_response?vacancyId=46117027
# https://hh.ru/applicant/vacancy_response?vacancyId=46117026
# https://hh.ru/applicant/vacancy_response?vacancyId=46258354
# https://hh.ru/applicant/vacancy_response?vacancyId=43528617
# https://hh.ru/applicant/vacancy_response?vacancyId=43528617
# https://hh.ru/applicant/vacancy_response?vacancyId=46256196
# https://hh.ru/applicant/vacancy_response?vacancyId=45125964
# https://hh.ru/applicant/vacancy_response?vacancyId=46335651
# https://hh.ru/applicant/vacancy_response?vacancyId=46023270
# https://hh.ru/applicant/vacancy_response?vacancyId=46524325
# https://hh.ru/applicant/vacancy_response?vacancyId=46460438
# https://hh.ru/applicant/vacancy_response?vacancyId=46519294
# https://hh.ru/applicant/vacancy_response?vacancyId=46690324
# https://hh.ru/applicant/vacancy_response?vacancyId=46056415
# https://hh.ru/applicant/vacancy_response?vacancyId=44433173
# https://hh.ru/applicant/vacancy_response?vacancyId=46535534
# https://hh.ru/applicant/vacancy_response?vacancyId=46705713
# https://hh.ru/applicant/vacancy_response?vacancyId=46559189
# https://hh.ru/applicant/vacancy_response?vacancyId=46177661
# https://hh.ru/applicant/vacancy_response?vacancyId=45355018
# https://hh.ru/applicant/vacancy_response?vacancyId=46111096
# https://hh.ru/applicant/vacancy_response?vacancyId=46132279
# https://hh.ru/applicant/vacancy_response?vacancyId=46531100
# https://hh.ru/applicant/vacancy_response?vacancyId=45960633
# https://hh.ru/applicant/vacancy_response?vacancyId=46445462
# https://hh.ru/applicant/vacancy_response?vacancyId=46446517
# https://hh.ru/applicant/vacancy_response?vacancyId=46100136
# https://hh.ru/applicant/vacancy_response?vacancyId=46446567
# https://hh.ru/applicant/vacancy_response?vacancyId=46446764
# https://hh.ru/applicant/vacancy_response?vacancyId=46531633
# https://hh.ru/applicant/vacancy_response?vacancyId=46609645
# https://hh.ru/applicant/vacancy_response?vacancyId=46639897
# https://hh.ru/applicant/vacancy_response?vacancyId=34847333
# https://hh.ru/applicant/vacancy_response?vacancyId=46246517
# https://hh.ru/applicant/vacancy_response?vacancyId=45975437
# https://hh.ru/applicant/vacancy_response?vacancyId=34847485
# https://hh.ru/applicant/vacancy_response?vacancyId=44887350
# https://hh.ru/applicant/vacancy_response?vacancyId=36618179
# https://hh.ru/applicant/vacancy_response?vacancyId=45766837
# https://hh.ru/applicant/vacancy_response?vacancyId=42226188
# https://hh.ru/applicant/vacancy_response?vacancyId=37942316
# https://hh.ru/applicant/vacancy_response?vacancyId=45407369
# https://hh.ru/applicant/vacancy_response?vacancyId=44362486
# https://hh.ru/applicant/vacancy_response?vacancyId=45407346
# https://hh.ru/applicant/vacancy_response?vacancyId=44362487
# https://hh.ru/applicant/vacancy_response?vacancyId=45973716
# https://hh.ru/applicant/vacancy_response?vacancyId=41096302
# https://hh.ru/applicant/vacancy_response?vacancyId=46390522
# https://hh.ru/applicant/vacancy_response?vacancyId=45586464
# https://hh.ru/applicant/vacancy_response?vacancyId=43674097
# https://hh.ru/applicant/vacancy_response?vacancyId=43298031
# https://hh.ru/applicant/vacancy_response?vacancyId=43674102
# https://hh.ru/applicant/vacancy_response?vacancyId=46417735
# https://hh.ru/applicant/vacancy_response?vacancyId=46725811
# https://hh.ru/applicant/vacancy_response?vacancyId=46451141
# https://hh.ru/applicant/vacancy_response?vacancyId=46469775
# https://hh.ru/applicant/vacancy_response?vacancyId=46574931
# https://hh.ru/applicant/vacancy_response?vacancyId=46393308
# https://hh.ru/applicant/vacancy_response?vacancyId=46690447
# https://hh.ru/applicant/vacancy_response?vacancyId=43856438
# https://hh.ru/applicant/vacancy_response?vacancyId=43674112
# https://hh.ru/applicant/vacancy_response?vacancyId=46199185
# https://hh.ru/applicant/vacancy_response?vacancyId=46665044
# https://hh.ru/applicant/vacancy_response?vacancyId=46305789
# https://hh.ru/applicant/vacancy_response?vacancyId=46295113
# https://hh.ru/applicant/vacancy_response?vacancyId=46743249
# https://hh.ru/applicant/vacancy_response?vacancyId=46246724
# https://hh.ru/applicant/vacancy_response?vacancyId=46284993
# https://hh.ru/applicant/vacancy_response?vacancyId=46571498
# https://hh.ru/applicant/vacancy_response?vacancyId=43674057
# https://hh.ru/applicant/vacancy_response?vacancyId=46706519
# https://hh.ru/applicant/vacancy_response?vacancyId=45872271
# https://hh.ru/applicant/vacancy_response?vacancyId=41095804
# https://hh.ru/applicant/vacancy_response?vacancyId=43242292
# https://hh.ru/applicant/vacancy_response?vacancyId=45831354
# https://hh.ru/applicant/vacancy_response?vacancyId=46100698
# https://hh.ru/applicant/vacancy_response?vacancyId=45349145
# https://hh.ru/applicant/vacancy_response?vacancyId=46090006
# https://hh.ru/applicant/vacancy_response?vacancyId=46090804
# https://hh.ru/applicant/vacancy_response?vacancyId=46181997
# https://hh.ru/applicant/vacancy_response?vacancyId=45958556
# https://hh.ru/applicant/vacancy_response?vacancyId=43315410
# https://hh.ru/applicant/vacancy_response?vacancyId=46130843
# https://hh.ru/applicant/vacancy_response?vacancyId=46129200
# https://hh.ru/applicant/vacancy_response?vacancyId=46391860
# https://hh.ru/applicant/vacancy_response?vacancyId=46489896
# https://hh.ru/applicant/vacancy_response?vacancyId=46491940
# https://hh.ru/applicant/vacancy_response?vacancyId=46354450
# https://hh.ru/applicant/vacancy_response?vacancyId=46405062
# https://hh.ru/applicant/vacancy_response?vacancyId=45157245
# https://hh.ru/applicant/vacancy_response?vacancyId=46373028
# https://hh.ru/applicant/vacancy_response?vacancyId=46212451
# https://hh.ru/applicant/vacancy_response?vacancyId=46391822
# https://hh.ru/applicant/vacancy_response?vacancyId=46705578
# https://hh.ru/applicant/vacancy_response?vacancyId=46547779
# https://hh.ru/applicant/vacancy_response?vacancyId=46196498
# https://hh.ru/applicant/vacancy_response?vacancyId=43674110
# https://hh.ru/applicant/vacancy_response?vacancyId=46529767
# https://hh.ru/applicant/vacancy_response?vacancyId=46532015
# https://hh.ru/applicant/vacancy_response?vacancyId=43889597
# https://hh.ru/applicant/vacancy_response?vacancyId=46176349
# https://hh.ru/applicant/vacancy_response?vacancyId=46078545
# https://hh.ru/applicant/vacancy_response?vacancyId=44570567
# https://hh.ru/applicant/vacancy_response?vacancyId=46303709
# https://hh.ru/applicant/vacancy_response?vacancyId=44168409
# https://hh.ru/applicant/vacancy_response?vacancyId=46428486
# https://hh.ru/applicant/vacancy_response?vacancyId=46428148
# https://hh.ru/applicant/vacancy_response?vacancyId=46639922
# https://hh.ru/applicant/vacancy_response?vacancyId=46645554
# https://hh.ru/applicant/vacancy_response?vacancyId=45888623
# https://hh.ru/applicant/vacancy_response?vacancyId=45888625
# https://hh.ru/applicant/vacancy_response?vacancyId=44652464
# https://hh.ru/applicant/vacancy_response?vacancyId=46574604
